# %%
import pandas as pd

# %%
pd.read_excel('data.xlsx')
# Out:
#              Marca temporal     NOMBRE       RUT.  1. Sueldo Base  \
# 0   2018-03-07 17:01:42.011    Cecilia  2464339-1               5
# 1   2018-03-07 17:01:58.201      PEDRO  4895576-3               5
# 2   2018-03-07 17:02:18.424      MARIA  3435584-0               1
# 3   2018-03-07 17:03:18.197   jeniffer  7818918-8               5
# 4   2018-03-07 17:03:23.654  Cristobal  5156970-9               5
# ..                      ...        ...        ...             ...
# 478 2018-03-15 14:56:29.197    claudia  5080025-4               5
# 479 2018-03-15 16:33:45.181    Claudio   128653-0               5
# 480 2018-03-16 10:18:05.945     Johana  1816438-5               5
# 481 2018-03-16 10:35:43.008     XIMENA  6321067-3               5
# 482 2018-03-16 15:12:26.348     SUSANA    53943-7               5
#
#      2. Movilización  3. Colación  \
# 0                  4            3
# 1                  5            4
# 2                  5            5
# ...
